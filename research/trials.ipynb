# %% [markdown]
# ConfigBox

# %%
import yaml
yaml_file_path="test.yaml"

#Open Yaml file and load it content
with open(yaml_file_path, 'r') as yaml_file:
    data=yaml.safe_load(yaml_file)
print(data)
print(type(data))
# Out:
# {'name': 'sanjiv', 'email': 'roniwatson42@gmail.com'}
# <class 'dict'>

# %%
data["name"]
# Out:
# 'sanjiv'

# %%
from box import ConfigBox
config_data=ConfigBox(data)
config_data.name
# Out:
# 'sanjiv'

# %% [markdown]
# Ensure Annotations

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(2,3)
# Out:
# 6

# %%
get_product(2,"3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_product(2,"3")
#
# File c:\Users\Ron\anaconda3\envs\chest\lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002019E4065F0> does not match annotation type <class 'int'>
